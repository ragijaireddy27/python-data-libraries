# %%
import pandas as pd
import numpy as np

# %%
s = pd.read_csv(r'C:\Users\jayan\Downloads\archive\pokemon_data.csv')

# %%
s.head()
# Out:
#    dexnum        name  generation  type1   type2         species  height  \
# 0       1   Bulbasaur           1  Grass  Poison    Seed Pokémon     0.7
# 1       2     Ivysaur           1  Grass  Poison    Seed Pokémon     1.0
# 2       3    Venusaur           1  Grass  Poison    Seed Pokémon     2.0
# 3       4  Charmander           1   Fire     NaN  Lizard Pokémon     0.6
# 4       5  Charmeleon           1   Fire     NaN   Flame Pokémon     1.1
#
#    weight  ability1     ability2  ... catch_rate  base_friendship  base_exp  \
# 0     6.9  Overgrow  Chlorophyll  ...         45               50        64
# 1    13.0  Overgrow  Chlorophyll  ...         45               50       142
# 2   100.0  Overgrow  Chlorophyll  ...         45               50       236
# 3     8.5     Blaze  Solar Power  ...         45               50        62
# 4    19.0     Blaze  Solar Power  ...         45               50       142
#
# ...

# %%
s.loc[1:5,['type2','type1','weight']]
# Out:
#     type2  type1  weight
# 1  Poison  Grass    13.0
# 2  Poison  Grass   100.0
# 3     NaN   Fire     8.5
# 4     NaN   Fire    19.0
# 5  Flying   Fire    90.5

# %%
s.loc[s['type2']=='poison']
# Out:
# Empty DataFrame
# Columns: [dexnum, name, generation, type1, type2, species, height, weight, ability1, ability2, hidden_ability, hp, attack, defense, sp_atk, sp_def, speed, total, ev_yield, catch_rate, base_friendship, base_exp, growth_rate, egg_group1, egg_group2, percent_male, percent_female, egg_cycles, special_group]
# Index: []
#
# [0 rows x 29 columns]

# %%
ss = pd.read_csv('C:\\Users\\jayan\\Downloads\\archive\\pokemon_data.csv')
ss.shape
# Out:
# (1025, 29)

# %%
ss.describe()
# Out:
#             dexnum   generation       height       weight           hp  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean    513.000000     4.741463     1.211610    66.981659    70.184390
# std     296.036315     2.633633     1.248167   121.275372    26.631054
# min       1.000000     1.000000     0.100000     0.100000     1.000000
# 25%     257.000000     3.000000     0.500000     8.500000    50.000000
# 50%     513.000000     5.000000     1.000000    28.000000    68.000000
# 75%     769.000000     7.000000     1.500000    70.000000    85.000000
# max    1025.000000     9.000000    20.000000   999.900000   255.000000
#
#             attack      defense       sp_atk       sp_def        speed  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean     77.521951    72.507317    70.080976    70.205854    67.186341
# std      29.782541    29.286972    29.658378    26.639329    28.717227
# ...

# %%
ss.loc[ss['weight']>18]
ss.loc[(ss['weight']>20) & (ss['height']>20)]
# Out:
# Empty DataFrame
# Columns: [dexnum, name, generation, type1, type2, species, height, weight, ability1, ability2, hidden_ability, hp, attack, defense, sp_atk, sp_def, speed, total, ev_yield, catch_rate, base_friendship, base_exp, growth_rate, egg_group1, egg_group2, percent_male, percent_female, egg_cycles, special_group]
# Index: []
#
# [0 rows x 29 columns]

# %%
ss.loc[1:2]# it show 1 is starting row and 2 is ending row
ss.at[1000,'name'] # it will show the what isthe that postion
# Out:
# 'Wo-Chien'

# %%
ss[ss['dexnum']>1000] it will show the above
# Out:
#       dexnum          name  generation     type1     type2  \
# 1000    1001      Wo-Chien           9      Dark     Grass
# 1001    1002     Chien-Pao           9      Dark       Ice
# 1002    1003       Ting-Lu           9      Dark    Ground
# 1003    1004        Chi-Yu           9      Dark      Fire
# 1004    1005  Roaring Moon           9    Dragon      Dark
# 1005    1006  Iron Valiant           9     Fairy  Fighting
# 1006    1007      Koraidon           9  Fighting    Dragon
# 1007    1008      Miraidon           9  Electric    Dragon
# 1008    1009  Walking Wake           9     Water    Dragon
# 1009    1010   Iron Leaves           9     Grass   Psychic
# 1010    1011       Dipplin           9     Grass    Dragon
# 1011    1012  Poltchageist           9     Grass     Ghost
# 1012    1013     Sinistcha           9     Grass     Ghost
# 1013    1014       Okidogi           9    Poison  Fighting
# 1014    1015     Munkidori           9    Poison   Psychic
# ...

# %%
#it will drop the that column permanently
#(ss.drop(labels='type2',axis=1,inplace=True)  )
# IF WE DROP the that colum but not permanently it will provide copy of after deleting that column not effectoriginal dataset
ss.drop(labels='type2',axis=1) #here inplace is false by default
# Out:
#       dexnum          name  generation     type1              species  height  \
# 0          1     Bulbasaur           1     Grass         Seed Pokémon     0.7
# 1          2       Ivysaur           1     Grass         Seed Pokémon     1.0
# 2          3      Venusaur           1     Grass         Seed Pokémon     2.0
# 3          4    Charmander           1      Fire       Lizard Pokémon     0.6
# 4          5    Charmeleon           1      Fire        Flame Pokémon     1.1
# ...      ...           ...         ...       ...                  ...     ...
# 1020    1021   Raging Bolt           9  Electric      Paradox Pokémon     5.2
# 1021    1022  Iron Boulder           9      Rock      Paradox Pokémon     1.5
# 1022    1023    Iron Crown           9     Steel      Paradox Pokémon     1.6
# 1023    1024     Terapagos           9    Normal         Tera Pokémon     0.2
# 1024    1025     Pecharunt           9    Poison  Subjugation Pokémon     0.3
#
# ...

# %%
# for assining or updating the value
ss.at[1024,'ability2']='generation'
ss.tail(1)
# Out:
#       dexnum       name  generation   type1  type2              species  \
# 1024    1025  Pecharunt           9  Poison  Ghost  Subjugation Pokémon
#
#       height  weight          ability1    ability2  ... base_friendship  \
# 1024     0.3     0.3  Poison Puppeteer  generation  ...               —
#
#       base_exp  growth_rate    egg_group1  egg_group2  percent_male  \
# 1024         —         Slow  Undiscovered         NaN           NaN
#
#       percent_female  egg_cycles special_group     ability
# 1024             NaN           —      Mythical  generation
#
# [1 rows x 30 columns]

# %%
# crearting column by default entites
ss['num']='nan'
ss.head()
# Out:
#    dexnum        name  generation  type1   type2         species  height  \
# 0       1   Bulbasaur           1  Grass  Poison    Seed Pokémon     0.7
# 1       2     Ivysaur           1  Grass  Poison    Seed Pokémon     1.0
# 2       3    Venusaur           1  Grass  Poison    Seed Pokémon     2.0
# 3       4  Charmander           1   Fire     NaN  Lizard Pokémon     0.6
# 4       5  Charmeleon           1   Fire     NaN   Flame Pokémon     1.1
#
#    weight  ability1     ability2  ... base_exp  growth_rate  egg_group1  \
# 0     6.9  Overgrow  Chlorophyll  ...       64  Medium Slow      Grass
# 1    13.0  Overgrow  Chlorophyll  ...      142  Medium Slow      Grass
# 2   100.0  Overgrow  Chlorophyll  ...      236  Medium Slow      Grass
# 3     8.5     Blaze  Solar Power  ...       62  Medium Slow     Dragon
# 4    19.0     Blaze  Solar Power  ...      142  Medium Slow     Dragon
#
#    egg_group2  percent_male  percent_female  egg_cycles  special_group  \
# ...

# %%
# we creating another column basing on conditiom
ss.loc[ss['egg_cycles']==20,'moretime']=True

# %%
ss.loc[ss['egg_group1']=='Grass',['top_rated','most_watched']]=[True,True]

# %%
ss
# Out:
#       dexnum          name  generation     type1    type2  \
# 0          1     Bulbasaur           1     Grass   Poison
# 1          2       Ivysaur           1     Grass   Poison
# 2          3      Venusaur           1     Grass   Poison
# 3          4    Charmander           1      Fire      NaN
# 4          5    Charmeleon           1      Fire      NaN
# ...      ...           ...         ...       ...      ...
# 1020    1021   Raging Bolt           9  Electric   Dragon
# 1021    1022  Iron Boulder           9      Rock  Psychic
# 1022    1023    Iron Crown           9     Steel  Psychic
# 1023    1024     Terapagos           9    Normal      NaN
# 1024    1025     Pecharunt           9    Poison    Ghost
#
#                   species  height  weight          ability1     ability2  ...  \
# 0            Seed Pokémon     0.7     6.9          Overgrow  Chlorophyll  ...
# 1            Seed Pokémon     1.0    13.0          Overgrow  Chlorophyll  ...
# ...

# %%
ss.head(5)
# Out:
#    dexnum        name  generation  type1   type2         species  height  \
# 0       1   Bulbasaur           1  Grass  Poison    Seed Pokémon     0.7
# 1       2     Ivysaur           1  Grass  Poison    Seed Pokémon     1.0
# 2       3    Venusaur           1  Grass  Poison    Seed Pokémon     2.0
# 3       4  Charmander           1   Fire     NaN  Lizard Pokémon     0.6
# 4       5  Charmeleon           1   Fire     NaN   Flame Pokémon     1.1
#
#    weight ability1     ability2  ... base_exp  growth_rate  egg_group1  \
# 0     6.9      NaN  Chlorophyll  ...       64  Medium Slow      Grass
# 1    13.0      NaN  Chlorophyll  ...      142  Medium Slow      Grass
# 2   100.0      NaN  Chlorophyll  ...      236  Medium Slow      Grass
# 3     8.5      NaN  Solar Power  ...       62  Medium Slow     Dragon
# 4    19.0      NaN  Solar Power  ...      142  Medium Slow     Dragon
#
#    egg_group2  percent_male  percent_female  egg_cycles  special_group  \
# ...

# %%
#ss.drop(labels='most_watched',axis=1,inplace=True)
#applying funtion to allow you to apply funtion on axis of the dataframe
ss['height']=ss['weight'].apply(lambda x:'long' if x>120 else 'shoert')
ss
# Out:
#       dexnum          name  generation     type1    type2  \
# 0          1     Bulbasaur           1     Grass   Poison
# 1          2       Ivysaur           1     Grass   Poison
# 2          3      Venusaur           1     Grass   Poison
# 3          4    Charmander           1      Fire      NaN
# 4          5    Charmeleon           1      Fire      NaN
# ...      ...           ...         ...       ...      ...
# 1020    1021   Raging Bolt           9  Electric   Dragon
# 1021    1022  Iron Boulder           9      Rock  Psychic
# 1022    1023    Iron Crown           9     Steel  Psychic
# 1023    1024     Terapagos           9    Normal      NaN
# 1024    1025     Pecharunt           9    Poison    Ghost
#
#                   species  height  weight ability1     ability2  ... base_exp  \
# 0            Seed Pokémon  shoert     6.9      NaN  Chlorophyll  ...       64
# 1            Seed Pokémon  shoert    13.0      NaN  Chlorophyll  ...      142
# ...

# %%
#mappingexisting values
ss['ability1']=ss['ability2'].map({'posion':'posion type','silver':'silver type'})

# %%
#replace the values
ss['type1'].replace('Grass','grasss',inplace=True)
ss.head(2)
# Out:
#    dexnum       name  generation   type1   type2       species  height  \
# 0       1  Bulbasaur           1  grasss  Poison  Seed Pokémon  shoert
# 1       2    Ivysaur           1  grasss  Poison  Seed Pokémon  shoert
#
#    weight ability1     ability2  ...  growth_rate  egg_group1  egg_group2  \
# 0     6.9      NaN  Chlorophyll  ...  Medium Slow      Grass      Monster
# 1    13.0      NaN  Chlorophyll  ...  Medium Slow      Grass      Monster
#
#    percent_male  percent_female  egg_cycles  special_group  ability moretime  \
# 0          87.5            12.5          20       Ordinary      nan      NaN
# 1          87.5            12.5          20       Ordinary      nan      NaN
#
#           type12
# 0  Grass(Poison)
# 1  Grass(Poison)
#
# [2 rows x 32 columns]

# %%
#adding new column based on calucluation
ss['type12']=ss['type1']+"("+ss['type2'].astype(str)+")"
#assigning to that to created colums:
ss=ss.assign{
# Out:
# dexnum                         1
# name                   Bulbasaur
# generation                     1
# type1                      Grass
# type2                     Poison
# species             Seed Pokémon
# height                    shoert
# weight                       6.9
# ability1                     NaN
# ability2             Chlorophyll
# hidden_ability               NaN
# hp                            45
# attack                        49
# defense                       49
# sp_atk                        65
# sp_def                        65
# speed                         45
# total                        318
# ev_yield               1 Sp. Atk
# catch_rate                    45
# base_friendship               50
# base_exp                      64
# growth_rate          Medium Slow
# egg_group1                Grass
# egg_group2               Monster
# percent_male                87.5
# percent_female              12.5
# egg_cycles                    20
# ...

# %%
ss=ss.assign(
    is_older=lambda x:x['attack']<30,
    duration_hour=lambda x:x['defense']/50) #adding multiple new colums

# %%
# we rename the index   # we can rename permanently by providing inplace =True
ss.index.names=['pokena_id']   
# renaming column indesxs
ss.rename(columns={'dexnum':'pokenum'}) # we can rename more column name at a single query only
# Out:
#            pokenum          name  generation     type1    type2  \
# pokena_id
# 0                1     Bulbasaur           1    grasss   Poison
# 1                2       Ivysaur           1    grasss   Poison
# 2                3      Venusaur           1    grasss   Poison
# 3                4    Charmander           1      Fire      NaN
# 4                5    Charmeleon           1      Fire      NaN
# ...            ...           ...         ...       ...      ...
# 1020          1021   Raging Bolt           9  Electric   Dragon
# 1021          1022  Iron Boulder           9      Rock  Psychic
# 1022          1023    Iron Crown           9     Steel  Psychic
# 1023          1024     Terapagos           9    Normal      NaN
# 1024          1025     Pecharunt           9    Poison    Ghost
#
#                        species  height  weight ability1     ability2  ...  \
# pokena_id                                                             ...
# ...

# %%
#diplaying optionts to maximum we we use head(),tail(0 it only show what we set taht only
pd.set_option('display.max_rows',10)
pd.set_option('display.max_columns',5)
# we can reset by the that otionts

pd.reset_option('display')

# %%
# Grouping Data by one cloumn
g=ss.groupby('type1')
# group by two columns
g=ss.groupby(['type1','type2'])

# %%
#aggregation
#simple aggregation -calucluation avg
avg=ss.groupby('type1')['hp'].mean()
avg
#multiple aggrgation on single column
aa=ss.groupby('type1')['hp'].agg([np.mean,np.std])
aa
#different aggregation on different columns
ca=ss.groupby('type1').agg({'hp':np.mean,'attack':np.min,'defense':'sum'})
ca
# Out:
# C:\Users\jayan\AppData\Local\Temp\ipykernel_15392\1096386382.py:6: FutureWarning: The provided callable <function mean at 0x00000178F1215EE0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   aa=ss.groupby('type1')['hp'].agg([np.mean,np.std])
# C:\Users\jayan\AppData\Local\Temp\ipykernel_15392\1096386382.py:6: FutureWarning: The provided callable <function std at 0x00000178F1216020> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   aa=ss.groupby('type1')['hp'].agg([np.mean,np.std])
# ...

# %%
#aggrigation with out grouping
ant=ss[['defense','attack']].describe()
ant
# Out:
#            defense       attack
# count  1025.000000  1025.000000
# mean     72.507317    77.521951
# std      29.286972    29.782541
# min       5.000000     5.000000
# 25%      50.000000    55.000000
# 50%      70.000000    75.000000
# 75%      90.000000   100.000000
# max     230.000000   181.000000

# %%
#it count not null value count
a=ss.count()
a
# Out:
# dexnum             1025
# name               1025
# generation         1025
# type1              1025
# type2               526
# species            1025
# height             1025
# weight             1025
# ability1              0
# ability2            859
# hidden_ability      530
# hp                 1025
# attack             1025
# defense            1025
# sp_atk             1025
# sp_def             1025
# speed              1025
# total              1025
# ev_yield           1025
# catch_rate         1025
# base_friendship    1025
# base_exp           1025
# growth_rate        1025
# egg_group1         1025
# egg_group2          279
# percent_male        870
# percent_female      870
# egg_cycles         1025
# special_group      1025
# ability            1025
# moretime              0
# type12             1025
# is_older           1025
# duration_hour      1025
# dtype: int64

# %%
ss['type12'].value_counts()
# Out:
# type12
# Normal(nan)      75
# Water(nan)       74
# Grass(nan)       47
# Psychic(nan)     39
# Fire(nan)        36
#                  ..
# Flying(Water)     1
# Poison(Bug)       1
# Dark(Normal)      1
# Ghost(Dark)       1
# Poison(Ghost)     1
# Name: count, Length: 203, dtype: int64

# %%
#using a custom funtion for aggregation
def range_fun(series):
    return series.max()-series.min()

range_by_gen=ss.groupby('type1')['hp'].agg(range_fun)
range_by_gen
# Out:
# type1
# Bug         106
# Dark        188
# Dragon      172
# Electric    105
# Fairy        91
# Fighting    124
# Fire         77
# Flying       60
# Ghost       130
# Ground      120
# Ice         140
# Normal      225
# Poison      105
# Psychic     170
# Rock         93
# Steel        95
# Water       160
# grasss       93
# Name: hp, dtype: int64

# %%
#renaming group aggregation results
renam=ss.groupby('type1')['hp'].agg([('average','mean'),('rat','std')])
renam
# Out:
#             average        rat
# type1
# Bug       56.493976  17.802695
# Dark      75.800000  33.267238
# Dragon    79.594595  30.638991
# Electric  64.779661  20.274893
# Fairy     71.379310  22.830765
# Fighting  76.075000  27.776016
# Fire      69.833333  19.502728
# Flying    70.000000  19.880895
# Ghost     61.800000  27.453490
# Ground    74.475000  26.412883
# Ice       75.709677  28.149830
# Normal    77.525424  34.808318
# Poison    70.571429  23.524915
# Psychic   71.783333  30.873768
# Rock      68.310345  22.389853
# Steel     71.666667  21.867131
# Water     70.865672  27.749359
# grasss    65.766990  19.777291
