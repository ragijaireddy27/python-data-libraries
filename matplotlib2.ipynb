# %%
from matplotlib.pylab import plt #or
from matplotlib import pylab as plt

# %%
import numpy as np

# %%
x=np.linspace(0,9,7,9)
y=x*x-1
print(x)
print(y)
# Out:
# [0.  1.5 3.  4.5 6.  7.5 9. ]
# [-1.    1.25  8.   19.25 35.   55.25 80.  ]

# %%
x=np.random.randn(10)
y=np.random.randn(10)
print(x)
print(y)
# Out:
# [-0.26910959  0.92694391  0.76396976 -0.20966506 -1.66690643  0.54432693
#   1.88928312  1.15168278  0.40255707 -0.58049626]
# [-1.22593539 -0.99142579 -0.39124653 -1.34081574  0.18854052 -1.21300559
#  -1.65885424  0.40701759 -0.5417951  -0.49898335]

# %%
fig,axes=plt.subplots() # we can draw empty graph sheets with empty 
#fig,axes=plt.subplots(nrows=2,ncols=2) # we draw no.of  empty graphs

# %%
line=axes.plot(x,x+4,color='black',lw=1.5)

# %%
"""fig,axes=plt.subplots(1,2,figsize=(10,5))
axes[0].plot(x,x**2,x,x**3,lw=2)
axes[0].grid(True)
axes[1].plot(x,x**2,x,x**3,lw=4)
axes.set_xlim([2,5])
axes.set_ylim([0,60])
axes[1].grid[True]
"""
# Out:
# 'fig,axes=plt.subplots(1,2,figsize=(10,5))\naxes[0].plot(x,x**2,x,x**3,lw=2)\naxes[0].grid(True)\naxes[1].plot(x,x**2,x,x**3,lw=4)\naxes.set_xlim([2,5])\naxes.set_ylim([0,60])\naxes[1].grid[True]\n'

# %% [markdown]
#        other 2d graphic

# %%
n=np.array([0,1,2,3,4.5])
fig,axes=plt.subplots(1,4,figsize=(16,5))
axes[0].set_title('scatter plot')
axes[0].scatter(x,x+0.25*np.random.randn(len(x)))
axes[1].step(n,n**2,lw=2)
axes[2].bar(n,n**2,align='center',width=0.5,alpha=0.5)
axes[3].fill_between(x,x**2,x**3,color='black',alpha=0.5)

# %%
#draw a rader chart
fig=plt.figure(figsize=(6,6))
axes=fig.add_axes([0.0,0.1,0.6,0.7],polar=True)
t=np.linspace(0,2*np.pi,100)
axes.plot(t,t*2,color='blue',lw=3)

# %%
#draw a histogram
n=np.random.randn(100000)
fig,axes=plt.subplots(1,2,figsize=(12,4))
axes[0].set_title("default histogram")
axes[0].hist(n)
axes[1].set_title("cumulative detailed histogram")
axes[1].hist(n,cumulative=True ,bins=50)
# Out:
# (array([1.0000e+00, 1.0000e+00, 2.0000e+00, 2.0000e+00, 2.0000e+00,
#         5.0000e+00, 1.0000e+01, 1.5000e+01, 3.4000e+01, 6.8000e+01,
#         1.1500e+02, 2.0700e+02, 3.7200e+02, 6.0700e+02, 1.0090e+03,
#         1.6590e+03, 2.5860e+03, 4.0440e+03, 6.0060e+03, 8.5140e+03,
#         1.1664e+04, 1.5778e+04, 2.0816e+04, 2.6641e+04, 3.3031e+04,
#         4.0114e+04, 4.7715e+04, 5.5176e+04, 6.2604e+04, 6.9533e+04,
#         7.5806e+04, 8.1288e+04, 8.5876e+04, 8.9690e+04, 9.2703e+04,
#         9.4988e+04, 9.6642e+04, 9.7830e+04, 9.8656e+04, 9.9173e+04,
#         9.9515e+04, 9.9735e+04, 9.9866e+04, 9.9922e+04, 9.9958e+04,
#         9.9983e+04, 9.9993e+04, 9.9994e+04, 9.9998e+04, 1.0000e+05]),
#  array([-5.15865498, -4.9697562 , -4.78085742, -4.59195863, -4.40305985,
#         -4.21416107, -4.02526229, -3.8363635 , -3.64746472, -3.45856594,
#         -3.26966715, -3.08076837, -2.89186959, -2.70297081, -2.51407202,
# ...

# %%
#draw contor image
import matplotlib.cm as cm
import numpy as np
import matplotlib.pyplot as plt

# %%
delta=0.025
x=np.arange(-3.0,3.0,delta)
y=np.arange(-2.0,2.0,delta)
x,y=np.meshgrid(x,y)
z1=np.exp(-x**2-y**2)
z2=np.exp(-(-x-1)**2-(y-1)**2)
z=z1+z2

# %%
fig,axes=plt.subplots()
cs=axes.contour(x,y,z)
axes.clabel(cs,inline=1) #if we require the frontsize is we applie
axes.set_title('contour map')
# Out:
# Text(0.5, 1.0, 'contour map')
